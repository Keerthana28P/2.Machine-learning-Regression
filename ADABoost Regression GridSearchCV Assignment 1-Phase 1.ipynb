# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
param_grid={'n_estimators':[10,30,50,70,100],'learning_rate':[0.1,0.5,1,2.5,5]}
grid=GridSearchCV(AdaBoostRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#Fitting the model for Grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.5, 1, 2.5, 5],
#                          'n_estimators': [10, 30, 50, 70, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'learning_rate': 0.1, 'n_estimators': 10}:

# %%
#to display the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.174918      0.005607         0.030260        0.003069
# 1        0.425088      0.003078         0.044035        0.004717
# 2        0.658594      0.013331         0.057247        0.006690
# 3        0.883347      0.052063         0.075441        0.005765
# 4        0.877266      0.108885         0.075383        0.011897
# 5        0.150914      0.003352         0.024228        0.001997
# 6        0.210510      0.024966         0.028827        0.004184
# 7        0.231729      0.042859         0.028888        0.003075
# 8        0.232021      0.048798         0.028833        0.006037
# 9        0.261530      0.030146         0.033113        0.003494
# 10       0.142936      0.015613         0.027836        0.003842
# 11       0.144130      0.027667         0.024719        0.005346
# 12       0.150806      0.019565         0.025494        0.003302
# 13       0.148588      0.020818         0.023770        0.002334
# 14       0.146795      0.019194         0.027119        0.004083
# 15       0.101921      0.027659         0.020900        0.002785
# 16       0.103681      0.027395         0.018050        0.002020
# 17       0.109815      0.024210         0.023639        0.005337
# 18       0.132169      0.037496         0.027805        0.005781
# 19       0.100792      0.030466         0.021127        0.005494
# 20       0.139437      0.006843         0.025048        0.003830
# 21       0.343328      0.004045         0.041114        0.001126
# 22       0.537972      0.008737         0.059335        0.002615
# 23       0.685999      0.020136         0.056623        0.004648
# 24       0.742004      0.077639         0.046557        0.008202
#
#     param_learning_rate  param_n_estimators  \
# 0                   0.1                  10
# 1                   0.1                  30
# 2                   0.1                  50
# 3                   0.1                  70
# 4                   0.1                 100
# 5                   0.5                  10
# 6                   0.5                  30
# 7                   0.5                  50
# 8                   0.5                  70
# 9                   0.5                 100
# 10                  1.0                  10
# 11                  1.0                  30
# 12                  1.0                  50
# 13                  1.0                  70
# 14                  1.0                 100
# 15                  2.5                  10
# 16                  2.5                  30
# 17                  2.5                  50
# 18                  2.5                  70
# 19                  2.5                 100
# 20                  5.0                  10
# 21                  5.0                  30
# 22                  5.0                  50
# 23                  5.0                  70
# 24                  5.0                 100
#
#                                          params  split0_test_score  \
# 0    {'learning_rate': 0.1, 'n_estimators': 10}           0.871295
# 1    {'learning_rate': 0.1, 'n_estimators': 30}           0.857844
# 2    {'learning_rate': 0.1, 'n_estimators': 50}           0.852279
# 3    {'learning_rate': 0.1, 'n_estimators': 70}           0.844280
# 4   {'learning_rate': 0.1, 'n_estimators': 100}           0.845412
# 5    {'learning_rate': 0.5, 'n_estimators': 10}           0.856334
# 6    {'learning_rate': 0.5, 'n_estimators': 30}           0.852850
# 7    {'learning_rate': 0.5, 'n_estimators': 50}           0.840351
# 8    {'learning_rate': 0.5, 'n_estimators': 70}           0.840481
# 9   {'learning_rate': 0.5, 'n_estimators': 100}           0.840143
# 10     {'learning_rate': 1, 'n_estimators': 10}           0.805916
# 11     {'learning_rate': 1, 'n_estimators': 30}           0.851443
# 12     {'learning_rate': 1, 'n_estimators': 50}           0.843332
# 13     {'learning_rate': 1, 'n_estimators': 70}           0.840498
# 14    {'learning_rate': 1, 'n_estimators': 100}           0.821335
# 15   {'learning_rate': 2.5, 'n_estimators': 10}           0.705949
# 16   {'learning_rate': 2.5, 'n_estimators': 30}           0.872556
# 17   {'learning_rate': 2.5, 'n_estimators': 50}           0.863134
# 18   {'learning_rate': 2.5, 'n_estimators': 70}           0.714737
# 19  {'learning_rate': 2.5, 'n_estimators': 100}           0.666460
# 20     {'learning_rate': 5, 'n_estimators': 10}           0.042706
# 21     {'learning_rate': 5, 'n_estimators': 30}          -0.433400
# 22     {'learning_rate': 5, 'n_estimators': 50}           0.217210
# 23     {'learning_rate': 5, 'n_estimators': 70}           0.012817
# 24    {'learning_rate': 5, 'n_estimators': 100}           0.157731
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.800806           0.879404           0.826849
# 1            0.790393           0.862571           0.821762
# 2            0.795321           0.851017           0.815031
# 3            0.786388           0.840979           0.811327
# 4            0.786560           0.841248           0.810844
# 5            0.794266           0.845545           0.818728
# 6            0.798422           0.838035           0.813168
# 7            0.782027           0.832793           0.810438
# 8            0.773694           0.832188           0.806779
# 9            0.779134           0.828235           0.809900
# 10           0.784887           0.854019           0.815365
# 11           0.768480           0.846134           0.820541
# 12           0.758596           0.830581           0.816438
# 13           0.791080           0.821975           0.818809
# 14           0.792226           0.833831           0.815239
# 15           0.780630           0.876524           0.825139
# 16           0.786912           0.668785           0.704932
# 17           0.635820           0.643602           0.689270
# 18           0.777423           0.707393           0.828549
# 19           0.782806           0.870955           0.829013
# 20          -1.512256           0.187898           0.207868
# 21          -0.775933          -0.567576           0.204056
# 22           0.039197          -0.125728          -0.027350
# 23          -0.163746          -0.216842           0.065508
# 24           0.154631           0.273529          -0.075342
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.862317         0.848134        0.029693                1
# 1            0.854160         0.837346        0.027519                2
# 2            0.845233         0.831776        0.022720                4
# 3            0.842451         0.825085        0.022845                6
# 4            0.836381         0.824089        0.022289                7
# 5            0.849576         0.832890        0.023154                3
# 6            0.836039         0.827703        0.019377                5
# 7            0.846438         0.822409        0.023584                9
# 8            0.844623         0.819553        0.026428               11
# 9            0.823752         0.816233        0.020922               15
# 10           0.836022         0.819242        0.023933               12
# 11           0.826923         0.822704        0.029454                8
# 12           0.853944         0.820578        0.033436               10
# 13           0.820796         0.818632        0.015831               13
# 14           0.830093         0.818545        0.014686               14
# 15           0.855666         0.808782        0.060699               16
# 16           0.852868         0.777211        0.079861               17
# 17           0.857046         0.737774        0.101544               19
# 18           0.592820         0.724185        0.079189               20
# 19           0.713181         0.772483        0.074507               18
# 20          -0.874089        -0.389575        0.688832               25
# 21           0.262993        -0.261972        0.419454               24
# 22           0.231369         0.066940        0.138852               22
# 23          -0.105447        -0.081542        0.105983               23
# 24           0.215571         0.145224        0.118579               21

# %%
#to get the input from the user
age_input=float(input('age:'))
bmi_input=float(input('BMI:'))
children_input=int(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# age: 34
# BMI: 23.5
# Children: 3
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
#to check the inputs with best model
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[18467.32003791]
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
#to save the model
import pickle
filename="finalized_model_ADAGS1.sav"
pickle.dump(grid,open(filename,'wb'))
