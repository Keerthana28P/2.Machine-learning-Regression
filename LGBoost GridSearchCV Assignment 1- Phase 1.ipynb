# %%
# !pip install lightgbm

# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from lightgbm import LGBMRegressor

# %%
param_grid={'max_depth':[3,6,12],'num_leaves':[3,5,10],'learning_rate':[0.01,0.05,0.1]}
grid=GridSearchCV(LGBMRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#Fitting the model for Grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
#print best parameter after tuning
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'learning_rate': 0.05, 'max_depth': 3, 'num_leaves': 10}:

# %%
#to display the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.624474      0.046887         0.009634        0.000859
# 1        0.859818      0.120230         0.009854        0.002009
# 2        1.205293      0.074340         0.009132        0.003840
# 3        0.510791      0.010312         0.011615        0.001820
# 4        0.866307      0.005322         0.010456        0.004052
# 5        1.693158      0.011287         0.009813        0.003028
# 6        0.535446      0.005140         0.008430        0.002532
# 7        0.866955      0.008130         0.007254        0.006267
# 8        1.690990      0.013304         0.010309        0.003501
# 9        0.530972      0.005709         0.011486        0.002001
# 10       0.830672      0.005738         0.011620        0.003139
# 11       1.173475      0.016790         0.006997        0.004500
# 12       0.536086      0.002707         0.008432        0.003640
# ...

# %%
#to get the input from the user
age_input=float(input('age:'))
bmi_input=float(input('BMI:'))
children_input=int(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# age: 34
# BMI: 23.5
# Children: 3
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
#to check the inputs with best model
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19710.49375783]

# %%
#to save the model
import pickle
filename="finalized_model_lGGS1.sav"
pickle.dump(grid,open(filename,'wb'))
