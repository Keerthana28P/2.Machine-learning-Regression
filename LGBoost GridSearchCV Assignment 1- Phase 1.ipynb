# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\keert\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\keert\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\keert\anaconda3\lib\site-packages (from lightgbm) (1.13.1)

# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from lightgbm import LGBMRegressor

# %%
param_grid={'max_depth':[3,6,12],'num_leaves':[1,3,5],'bagging_fraction':[0.5,0.7,1],'learning_rate':[0.01,0.05,0.1]}
grid=GridSearchCV(LGBMRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#Fitting the model for Grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 135 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\sklearn.py", line 1189, in fit
#     super().fit(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\sklearn.py", line 955, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\engine.py", line 282, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\basic.py", line 3637, in __init__
#     train_set.construct()
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\basic.py", line 2576, in construct
#     self._lazy_init(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\basic.py", line 2168, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\basic.py", line 2303, in __init_from_np2d
#     _safe_call(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\lightgbm\basic.py", line 296, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Check failed: (num_leaves) > (1) at D:\a\1\s\lightgbm-python\src\io\config_auto.cpp, line 343 .
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan 0.67175546 0.7267932         nan 0.67175546 0.7267932
#         nan 0.67175546 0.7267932         nan 0.85082165 0.86114378
#         nan 0.85082165 0.86131907        nan 0.85082165 0.86131907
#         nan 0.85961696 0.85959006        nan 0.85961696 0.85917903
#         nan 0.85961696 0.85917903        nan 0.67175546 0.7267932
#         nan 0.67175546 0.7267932         nan 0.67175546 0.7267932
#         nan 0.85082165 0.86114378        nan 0.85082165 0.86131907
#         nan 0.85082165 0.86131907        nan 0.85961696 0.85959006
#         nan 0.85961696 0.85917903        nan 0.85961696 0.85917903
#         nan 0.67175546 0.7267932         nan 0.67175546 0.7267932
#         nan 0.67175546 0.7267932         nan 0.85082165 0.86114378
#         nan 0.85082165 0.86131907        nan 0.85082165 0.86131907
#         nan 0.85961696 0.85959006        nan 0.85961696 0.85917903
#         nan 0.85961696 0.85917903]
#   warnings.warn(
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 1338, number of used features: 5
# [LightGBM] [Info] Start training from score 13270.422260
# GridSearchCV(estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'bagging_fraction': [0.5, 0.7, 1],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 6, 12], 'num_leaves': [1, 3, 5]},
#              verbose=3)

# %%
#print best parameter after tuning
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'bagging_fraction': 0.5, 'learning_rate': 0.05, 'max_depth': 6, 'num_leaves': 5}:

# %%
#to display the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.169565      0.012614         0.000000        0.000000
# 1        0.431561      0.138198         0.009710        0.001733
# 2        0.698435      0.097234         0.006733        0.003343
# 3        0.007700      0.005281         0.000000        0.000000
# 4        0.415327      0.006174         0.008222        0.002871
# ..            ...           ...              ...             ...
# 76       0.461592      0.028563         0.006659        0.005500
# 77       0.721414      0.012449         0.003518        0.003104
# 78       0.010763      0.002904         0.000000        0.000000
# 79       0.459931      0.004568         0.010421        0.001641
# 80       0.545768      0.085527         0.002450        0.003972
#
#     param_bagging_fraction  param_learning_rate  param_max_depth  \
# 0                      0.5                 0.01                3
# 1                      0.5                 0.01                3
# 2                      0.5                 0.01                3
# 3                      0.5                 0.01                6
# 4                      0.5                 0.01                6
# ..                     ...                  ...              ...
# 76                     1.0                 0.10                6
# 77                     1.0                 0.10                6
# 78                     1.0                 0.10               12
# 79                     1.0                 0.10               12
# 80                     1.0                 0.10               12
#
#     param_num_leaves                                             params  \
# 0                  1  {'bagging_fraction': 0.5, 'learning_rate': 0.0...
# 1                  3  {'bagging_fraction': 0.5, 'learning_rate': 0.0...
# 2                  5  {'bagging_fraction': 0.5, 'learning_rate': 0.0...
# 3                  1  {'bagging_fraction': 0.5, 'learning_rate': 0.0...
# 4                  3  {'bagging_fraction': 0.5, 'learning_rate': 0.0...
# ..               ...                                                ...
# 76                 3  {'bagging_fraction': 1, 'learning_rate': 0.1, ...
# 77                 5  {'bagging_fraction': 1, 'learning_rate': 0.1, ...
# 78                 1  {'bagging_fraction': 1, 'learning_rate': 0.1, ...
# 79                 3  {'bagging_fraction': 1, 'learning_rate': 0.1, ...
# 80                 5  {'bagging_fraction': 1, 'learning_rate': 0.1, ...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0                 NaN                NaN                NaN
# 1            0.693618           0.637018           0.675590
# 2            0.753157           0.692991           0.729959
# 3                 NaN                NaN                NaN
# 4            0.693618           0.637018           0.675590
# ..                ...                ...                ...
# 76           0.885253           0.812363           0.885799
# 77           0.882722           0.810591           0.890712
# 78                NaN                NaN                NaN
# 79           0.885253           0.812363           0.885799
# 80           0.882722           0.810591           0.890712
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0                 NaN                NaN              NaN             NaN
# 1            0.667283           0.685269         0.671755        0.019504
# 2            0.724248           0.733612         0.726793        0.019497
# 3                 NaN                NaN              NaN             NaN
# 4            0.667283           0.685269         0.671755        0.019504
# ..                ...                ...              ...             ...
# 76           0.849824           0.864846         0.859617        0.027199
# 77           0.849751           0.862118         0.859179        0.028309
# 78                NaN                NaN              NaN             NaN
# 79           0.849824           0.864846         0.859617        0.027199
# 80           0.849751           0.862118         0.859179        0.028309
#
#     rank_test_score
# 0                55
# 1                46
# 2                37
# 3                55
# 4                46
# ..              ...
# 76               10
# 77               22
# 78               55
# 79               10
# 80               22
#
# [81 rows x 17 columns]

# %%
#to get the input from the user
age_input=float(input('age:'))
bmi_input=float(input('BMI:'))
children_input=int(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# age: 34
# BMI: 23.5
# Children: 3
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
#to check the inputs with best model
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# Future_Prediction=[19819.30809028]

# %%
#to save the model
import pickle
filename="finalized_model_lGGS1.sav"
pickle.dump(grid,open(filename,'wb'))
