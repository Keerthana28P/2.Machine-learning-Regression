# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
#model creation
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['None','sqrt','log2'],'splitter':['best','random']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#Fitting the model for Grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.66529065 0.66427232 0.64431774 0.61511996
#         nan        nan 0.60252866 0.62956141 0.6631354  0.67508641
#         nan        nan 0.70749939 0.62772999 0.68187118 0.64807893
#         nan        nan 0.65463845 0.64486993 0.68351168 0.66467771]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['None', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
#to display the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002216      0.000983         0.000000        0.000000
# 1        0.002538      0.000726         0.000000        0.000000
# 2        0.025734      0.023381         0.021700        0.033081
# 3        0.023507      0.030016         0.030210        0.031964
# 4        0.019166      0.020328         0.023197        0.023489
# 5        0.027622      0.023863         0.004451        0.000612
# 6        0.003832      0.004157         0.000000        0.000000
# 7        0.016978      0.029169         0.000000        0.000000
# 8        0.088972      0.027716         0.004436        0.000984
# 9        0.109916      0.029673         0.005808        0.001773
# 10       0.065283      0.024162         0.010997        0.012909
# 11       0.052564      0.006660         0.015322        0.020076
# 12       0.001509      0.000779         0.000000        0.000000
# 13       0.006244      0.007882         0.000000        0.000000
# 14       0.019279      0.022266         0.005188        0.000946
# 15       0.008362      0.000922         0.006675        0.004259
# 16       0.025935      0.032041         0.005235        0.001267
# 17       0.014103      0.009638         0.021237        0.023365
# 18       0.001604      0.000802         0.000000        0.000000
# 19       0.001771      0.000672         0.000000        0.000000
# 20       0.028535      0.028690         0.006665        0.002991
# 21       0.016375      0.008058         0.006254        0.003004
# 22       0.019855      0.012914         0.004535        0.000907
# 23       0.020313      0.012195         0.004557        0.001088
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.649276
# 3   {'criterion': 'squared_error', 'max_features':...           0.674182
# 4   {'criterion': 'squared_error', 'max_features':...           0.720366
# 5   {'criterion': 'squared_error', 'max_features':...           0.619665
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.719293
# 9   {'criterion': 'absolute_error', 'max_features'...           0.608917
# 10  {'criterion': 'absolute_error', 'max_features'...           0.674014
# 11  {'criterion': 'absolute_error', 'max_features'...           0.658885
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.743479
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.672506
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.662168
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.694857
# 18  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.781934
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.714279
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.749887
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.707378
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.606108           0.707488           0.669808
# 3            0.661327           0.695967           0.640016
# 4            0.613937           0.683287           0.461682
# 5            0.467027           0.631084           0.693993
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.581425           0.648911           0.464558
# 9            0.568584           0.729351           0.573169
# 10           0.632005           0.679858           0.659106
# 11           0.643240           0.731549           0.629586
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.609709           0.750202           0.708849
# 15           0.627599           0.701570           0.533474
# 16           0.616213           0.682745           0.669199
# 17           0.544881           0.661410           0.660234
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.525100           0.705230           0.522897
# 21           0.611382           0.638483           0.595652
# 22           0.567992           0.675774           0.668795
# 23           0.480660           0.739615           0.619581
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.693773         0.665291        0.035697                5
# 3            0.649871         0.664272        0.019530                7
# 4            0.742317         0.644318        0.101178               12
# 5            0.663832         0.615120        0.078487               15
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.598455         0.602529        0.084004               16
# 9            0.667785         0.629561        0.061227               13
# 10           0.670695         0.663135        0.016973                8
# 11           0.712172         0.675086        0.039775                4
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.725257         0.707499        0.050986                1
# 15           0.603500         0.627730        0.058187               14
# 16           0.779031         0.681871        0.053480                3
# 17           0.679012         0.648079        0.053142               10
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.738031         0.654638        0.109411                9
# 21           0.664554         0.644870        0.041928               11
# 22           0.755110         0.683512        0.068049                2
# 23           0.776154         0.664678        0.105605                6

# %%
#to get the input from the user
age_input=float(input('age:'))
bmi_input=float(input('BMI:'))
children_input=int(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# age: 34
# BMI: 23.5
# Children: 3
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
#to check the inputs with best model
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[17663.1442]
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
#to save the model
import pickle
filename="finalized_model_DTGS1.sav"
pickle.dump(grid,open(filename,'wb'))
