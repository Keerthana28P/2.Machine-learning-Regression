# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
#model creation
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['None','sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#Fitting the model for Grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 31 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.80588354 0.8348608  0.80858636 0.83447911
#         nan        nan 0.81893471 0.83270266 0.81604353 0.83260851
#         nan        nan 0.81887307 0.83483062 0.82176101 0.83365949
#         nan        nan 0.8205986  0.8321734  0.8123154  0.83352457]
#   warnings.warn(
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['None', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
#to display the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002831      0.000999         0.000000        0.000000
# 1        0.006778      0.003894         0.000000        0.000000
# 2        0.210252      0.087526         0.021845        0.021658
# 3        1.490981      0.364256         0.078260        0.029996
# 4        0.108737      0.070346         0.015075        0.010906
# 5        1.025198      0.630180         0.060899        0.036699
# 6        0.002541      0.001954         0.000000        0.000000
# 7        0.002679      0.003468         0.000000        0.000000
# 8        0.388387      0.220130         0.019200        0.013818
# 9        5.496416      1.748255         0.078920        0.029563
# 10       0.646433      0.028596         0.027462        0.001388
# 11       6.379525      0.035918         0.098354        0.008146
# 12       0.010891      0.005438         0.000000        0.000000
# 13       0.008392      0.003296         0.000000        0.000000
# 14       0.199684      0.006300         0.027350        0.003578
# 15       1.534682      0.534529         0.081152        0.026450
# 16       0.208575      0.006742         0.031162        0.001990
# 17       1.861018      0.035108         0.098568        0.005391
# 18       0.008679      0.007271         0.000000        0.000000
# 19       0.009406      0.002937         0.000000        0.000000
# 20       0.306582      0.008883         0.032782        0.005594
# 21       2.598769      0.025381         0.083901        0.006233
# 22       0.306089      0.002932         0.033486        0.003129
# 23       2.408224      0.040533         0.059791        0.007383
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               None                  10
# 13    friedman_mse               None                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
# 18         poisson               None                  10
# 19         poisson               None                 100
# 20         poisson               sqrt                  10
# 21         poisson               sqrt                 100
# 22         poisson               log2                  10
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.833850
# 3   {'criterion': 'squared_error', 'max_features':...           0.859246
# 4   {'criterion': 'squared_error', 'max_features':...           0.841752
# 5   {'criterion': 'squared_error', 'max_features':...           0.859867
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.849993
# 9   {'criterion': 'absolute_error', 'max_features'...           0.854494
# 10  {'criterion': 'absolute_error', 'max_features'...           0.849464
# 11  {'criterion': 'absolute_error', 'max_features'...           0.859606
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.842037
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.859133
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.835441
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.860302
# 18  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.843441
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856304
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.843654
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.857884
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.750271           0.826664           0.790850
# 3            0.779660           0.862332           0.830222
# 4            0.755935           0.837211           0.803467
# 5            0.782437           0.860531           0.828193
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.758604           0.857254           0.803134
# 9            0.780536           0.853958           0.828444
# 10           0.749488           0.839337           0.813841
# 11           0.777648           0.856555           0.827650
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.767683           0.853949           0.814237
# 15           0.778689           0.863818           0.828742
# 16           0.768691           0.857503           0.816100
# 17           0.777186           0.863195           0.830157
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.778704           0.827716           0.817083
# 21           0.777782           0.857602           0.826633
# 22           0.753756           0.838488           0.793525
# 23           0.782586           0.859024           0.827370
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.827783         0.805884        0.031662               16
# 3            0.842843         0.834861        0.029939                1
# 4            0.804567         0.808586        0.030770               15
# 5            0.841367         0.834479        0.028701                3
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.825688         0.818935        0.035688               11
# 9            0.846080         0.832703        0.027731                6
# 10           0.828087         0.816044        0.035324               13
# 11           0.841585         0.832609        0.029759                7
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.816460         0.818873        0.029714               12
# 15           0.843771         0.834831        0.030659                2
# 16           0.831071         0.821761        0.029664                9
# 17           0.837458         0.833659        0.030978                4
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.836050         0.820599        0.022710               10
# 21           0.842546         0.832173        0.029413                8
# 22           0.832154         0.812315        0.034185               14
# 23           0.840758         0.833525        0.028030                5

# %%
#to get the input from the user
age_input=float(input('age:'))
bmi_input=float(input('BMI:'))
children_input=int(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# age: 34
# BMI: 23.5
# Children: 3
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
#to check the inputs with best model
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[18976.4735042]
# C:\Users\keert\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
#to save the model
import pickle
filename="finalized_model_RFGS1.sav"
pickle.dump(grid,open(filename,'wb'))
