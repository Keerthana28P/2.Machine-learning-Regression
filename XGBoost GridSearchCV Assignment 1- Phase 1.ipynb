# %%
# !pip install xgboost

# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from xgboost import XGBRegressor

# %%
param_grid={'max_depth':[6,10,50],'min_child_weight':[1,3,5],'subsample':[0.3,0.5,1],'colsample':[0.1,0.5,1],'learning_rate':[0.1,0.5,1]}
grid=GridSearchCV(XGBRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#Fitting the model for Grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# C:\Users\keert\Anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [13:04:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "colsample" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
# ...

# %%
#print best parameter after tuning
re=grid.cv_results_
print("The R_Score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter {'colsample': 0.1, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 1}:

# %%
#to display the table
table=pd.DataFrame.from_dict(re)
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.103576      0.008883         0.009530        0.000751
# 1         0.112459      0.006023         0.011326        0.001296
# 2         0.095267      0.003978         0.008728        0.000873
# 3         0.089269      0.003052         0.009164        0.002159
# 4         0.083928      0.006249         0.007728        0.001030
# ..             ...           ...              ...             ...
# 238       0.691773      0.007212         0.030927        0.002587
# 239       1.094431      0.028094         0.027718        0.006400
# 240       0.335122      0.014458         0.025358        0.003067
# 241       0.435536      0.022362         0.025054        0.007588
# 242       0.469707      0.039259         0.018495        0.001752
#
#      param_colsample  param_learning_rate  param_max_depth  \
# 0                0.1                  0.1                6
# ...

# %%
#to get the input from the user
age_input=float(input('age:'))
bmi_input=float(input('BMI:'))
children_input=int(input('Children:'))
sex_male_input=int(input('Sex Male 0 or 1:'))
smoker_yes_input=int(input('Smoker yes 0 or 1:'))
# Out:
# age: 34
# BMI: 23.5
# Children: 3
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
#to check the inputs with best model
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[20913.766]

# %%
#to save the model
import pickle
filename="finalized_model_XGGS1.sav"
pickle.dump(grid,open(filename,'wb'))
